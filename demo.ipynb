# %% [markdown]
# # import

# %%
import pandas as pd
from kltn_utils.cbm import const as cbm_const

# %%
dataset_names = ["isic2018", "lcc", "nct", "idrid", "busi"]

for dataset_name in dataset_names: 
    print(f"{dataset_name} len concepts: {len(cbm_const.CLASS_AND_CONCEPT[dataset_name]['concepts'])}")
# Out:
# isic2018 len concepts: 760
# lcc len concepts: 568
# nct len concepts: 924
# idrid len concepts: 500
# busi len concepts: 500

# %%
for dataset_name in dataset_names: 
    print(f"{dataset_name} sample: {cbm_const.CLASS_AND_CONCEPT[dataset_name]['concepts'][:5]}")
# Out:
# isic2018 sample: ['has a pink color', 'displays a red hue', 'can show a brown shade', 'may have a white coloration', 'sometimes presents with yellow tones']
# lcc sample: ['shows hematoxylin-stained dark blue nuclei', 'shows eosin-stained pink cytoplasm', 'has areas of intense basophilia in crowded tumor cell nuclei', 'has areas of increased eosinophilia in tumor cytoplasm', 'may display pale mucin pools with lightly stained background']
# nct sample: ['shows large clear round spaces consistent with fat vacuoles', 'has adipocytes with empty-looking cytoplasm', 'displays a honeycomb-like pattern of large voids', 'appears predominantly white or very pale', 'contains thin pink septa between fat lobules']
# idrid sample: ['healthy retina', 'normal fundus image', 'no apparent diabetic retinopathy', 'no visible microaneurysms', 'absence of retinal hemorrhages']
# ...

# %%
concept2class = [[1,2], [0]]
a = type(concept2class[0]).__name__ == "list"
print(a)
# Out:
# True

# %%
clip_model_names = ["ViT-B-32", "ViT-B-16", "ViT-L-14", 
                   "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"]

for clip_model_name in clip_model_names: 
    print(f"clip_model_name: {clip_model_name}")
    model, tokenizer = kltn_utils.build_clip_model(clip_model_name)

    try:
        D = model.visual.output_dim
        print(f"clip_model_name: {clip_model_name} ok")
        print(f"D: {D}")
    except Exception as e:
        print(f"clip_model_name: {clip_model_name} error: {e}")
        
    print()

# %%
clip_model_names = ["hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"]

for clip_model_name in clip_model_names: 
    print(f"clip_model_name: {clip_model_name}")
    model, tokenizer = kltn_utils.build_clip_model(clip_model_name)

    try:
        D = model.visual.output_dim
        print(f"clip_model_name: {clip_model_name} ok")
        print(f"D: {D}")
    except Exception as e:
        print(f"clip_model_name: {clip_model_name} error: {e}")
        
    print()

# %%
from huggingface_hub import hf_hub_download

def get_clip_embed_dim_from_hf_hub(clip_model_name: str) -> int:
    # clip_model_name: "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
    repo_id = clip_model_name.removeprefix("hf-hub:")
    config_path = hf_hub_download(repo_id=repo_id, filename="open_clip_config.json")

    cfg = kltn_utils.read_json_to_dict(config_path)

    return cfg["model_cfg"]["embed_dim"]


get_clip_embed_dim_from_hf_hub("hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224")
